# %% [markdown]
# ## 1. 뉴스제목 가져오기
# * user-agent 요청헤더를 반드시 설정해야 한다.

# %%
# requests 라이브러리 설치여부 확인
# !pip show requests
# Out:
# Name: requests
# Version: 2.32.3
# Summary: Python HTTP for Humans.
# Home-page: https://requests.readthedocs.io
# Author: Kenneth Reitz
# Author-email: me@kennethreitz.org
# License: Apache-2.0
# Location: C:\Users\USER\anaconda3\Lib\site-packages
# Requires: certifi, charset-normalizer, idna, urllib3
# Required-by: anaconda-auth, anaconda-catalogs, anaconda-client, anaconda-project, conda, conda-build, conda-repo-cli, conda_package_streaming, jupyterlab_server, pandas-profiling, requests-toolbelt, tensorflow

# %%
# beautifulsoup4 라이브러리 설치여부 확인
# !pip show beautifulsoup4
# Out:
# Name: beautifulsoup4
# Version: 4.12.3
# Summary: Screen-scraping library
# Home-page:
# Author:
# Author-email: Leonard Richardson <leonardr@segfault.org>
# License: MIT License
# Location: C:\Users\USER\anaconda3\Lib\site-packages
# Requires: soupsieve
# Required-by: conda-build, nbconvert

# %%
# reqeusts, bs4 import
import requests
# BeautifulSoup import
import bs4 
# BeautifulSoup 클래스 import
from bs4 import BeautifulSoup

# %%
# requests, bs4 버전 확인하기
print(f'requests 버전 = {requests.__version__}')
print(f'bs4 버전 = {requests.__version__}')

# %% [markdown]
# ### 1. 뉴스 제목 추출하기

# %%
# IT/과학 뉴스 
req_param = {
    'sid': 105
}

# 105번 뉴스만 보겠다고 고정시킴
sid = 105
# url = f'https://news.naver.com/section/{sid}' 
url = 'https://news.naver.com/section/{sid}'.format(**req_param)
print(url)
# Out:
# https://news.naver.com/section/105

# %%
# IT/과학 뉴스 
req_param = {
    'sid': 105
}

# {문자열} = 동적인 변수
url = 'https://news.naver.com/section/{sid}'.format(**req_param)
print(url)


# 요청 헤더 설정 : 브라우저 정보
req_header = {
    "user-agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/104.0.0.0 Safari/537.36"""
}
 

# requests 의 get() 함수 호출하기 
res = requests.get(url, headers=req_header)
print(res.status_code)
print(type(res))
print(res)

# 응답(response)이 OK 이면
# 응답 (response)에서 text 추출
# BeautifulSoup 객체 생성  
# CSS 선택자
# print(soup.select("div.sa_text a[href*='mnews/article']"))

# <a> 태그 리스트 순회하기    

# 응답(response)이 Error 이면 status code 출력
# Out:
# 200
# <class 'requests.models.Response'>
# <Response [200]>

# %% [markdown]
# ### 1.1 뉴스제목 추출하는 함수 선언하기

# %%
import requests
from bs4 import BeautifulSoup

section_dict = {100:'정치',101:'경제',102:'사회',103:'생활/문화',104:'세계',105:'IT/과학'}

def print_news(sid, section):  #print_new(103,'생활/문화') 
    pass

# %%
print_news(103,section_dict[103])

# %% [markdown]
# ### 2. Image 다운로드
# * referer 요청 헤더를 반드시 설정해야 한다.

# %%
import requests
import os

req_header = {
    'referer':'https://comic.naver.com/webtoon/detail?titleId=835751&no=24&week=tue',
    "user-agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/104.0.0.0 Safari/537.36"""
}

img_urls = [
    'https://image-comic.pstatic.net/webtoon/835751/24/20250623151113_4a032791c141c6f022bdc38c218efdf2_IMAG01_1.jpg',
    'https://image-comic.pstatic.net/webtoon/835751/24/20250623151113_4a032791c141c6f022bdc38c218efdf2_IMAG01_2.jpg',
    'https://image-comic.pstatic.net/webtoon/835751/24/20250623151113_4a032791c141c6f022bdc38c218efdf2_IMAG01_3.jpg'
    ]

for img_url in img_urls:
    # requests 의 get(url, headers) 함수 호출하기 
    res = requests.get(img_url, headers=req_header)
    print(res.ok, res.status_code)
    if res.ok:
        # binary 응답 데이터 가져오기
        img_data = res.content
        print(img_data)
        # url에서 파일명만 추출하기
        file_name = os.path.basename(img_url)
        print(file_name)
        # binday data를 file에 write하기
        with open(file_name, 'wb') as file:
            print(f'Writing to {file_name}({len(img_data):,}bytes)')
            file.write(img_data)
# Out:
# True 200
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x02\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00C\x00\x03\x02\x02\x03\x02\x02\x03\x03\x03\x03\x04\x03\x03\x04\x05\x08\x05\x05\x04\x04\x05\n\x07\x07\x06\x08\x0c\n\x0c\x0c\x0b\n\x0b\x0b\r\x0e\x12\x10\r\x0e\x11\x0e\x0b\x0b\x10\x16\x10\x11\x13\x14\x15\x15\x15\x0c\x0f\x17\x18\x16\x14\x18\x12\x14\x15\x14\xff\xdb\x00C\x01\x03\x04\x04\x05\x04\x05\t\x05\x05\t\x14\r\x0b\r\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\xff\xc0\x00\x11\x08\x06@\x02\xb2\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1f\x00\x00\x01\x05\x01\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\x06\x07\x08\t\n\x0b\xff\xc4\x00\xb5\x10\x00\x02\x01\x03\x03\x02\x04\x03\x05\x05\x04\x04\x00\x00\x01}\x01\x02\x03\x00\x04\x11\x05\x12!1A\x06\x13Qa\x07"q\x142\x81\x91\xa1\x08#B\xb1\xc1\x15R\xd1\xf0$3br\x82\t\n\x16\x17\x18\x19\x1a%&\'()*456789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz\t\n\x0b\xff\xc4\x00\xb5\x11\x00\x02\x01\x02\x04\x04\x03\x04\x07\x05\x04\x04\x00\x01\x02w\x00\x01\x02\x03\x11\x04\x05!1\x06\x12AQ\x07aq\x13"2\x81\x08\x14B\x91\xa1\xb1\xc1\t#3R\xf0\x15br\xd1\n\x16$4\xe1%\xf1\x17\x18\x19\x1a&\'()*56789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz?\x00\xfdS\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\x ...
# 20250623151113_4a032791c141c6f022bdc38c218efdf2_IMAG01_1.jpg
# Writing to 20250623151113_4a032791c141c6f022bdc38c218efdf2_IMAG01_1.jpg(110,240bytes)
# True 200
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x02\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00C\x00\x03\x02\x02\x03\x02\x02\x03\x03\x03\x03\x04\x03\x03\x04\x05\x08\x05\x05\x04\x04\x05\n\x07\x07\x06\x08\x0c\n\x0c\x0c\x0b\n\x0b\x0b\r\x0e\x12\x10\r\x0e\x11\x0e\x0b\x0b\x10\x16\x10\x11\x13\x14\x15\x15\x15\x0c\x0f\x17\x18\x16\x14\x18\x12\x14\x15\x14\xff\xdb\x00C\x01\x03\x04\x04\x05\x04\x05\t\x05\x05\t\x14\r\x0b\r\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\xff\xc0\x00\x11\x08\x06@\x02\xb2\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1f\x00\x00\x01\x05\x01\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\
ee\xe3\xc8\xb6\xb5aq\x92\xac@#ss\x83\xc08\x03>\xc3\xa8\xae\xd6\xb1\xbfg\xad+\xfe\x12\xaf\xdaW\\\xb9\xb9\x8f\xcd\xb5\xd3\xacd\x00\x12\n\x82v\xa2\xf6\x04\x1f\x99\xb9\x1c\x83\xc7J\xb8G\x9d\xd8\x1c\xb9"\xe6\xfa\x1fdC<w\x11$\xb18\x926\x19VC\x90E>\xb8\xbb\x9f\x02\xea>\x1e\xb9\x92\xf7\xc37x\x04\x1d\xd6\x17,Lm\xf4$\xf5\xcf\xae8\xefD?\x11[M\x97\xc8\xf1\x06\x97s\xa5H\x07\x12\x85/\x1bt\xce\x08\xe7\xa9\xed\x9f\xadaS\x0f8y\xa0\xa7^\x15\x16\x8fSc\xc6>\t\xd1<}\xa2\xc9\xa5k\xda|Z\x85\x93\x10\xc1d\xc8ea\xd1\x95\x86\n\xb0\xf5\x07\xdb\xa5|\xe3\xe2\x8f\xd9g\xc4\xbe\n\xbe\x9fQ\xf8w\xac\xf9\x96\x8c7I\xa5\xdd\xed\xf3\x0e:\x05b6\xb1\xc7\xae\x0f\xb9\xcd}=\xa7j\xf6Z\xb4b[+\xa8\ ...
# 20250623151113_4a032791c141c6f022bdc38c218efdf2_IMAG01_3.jpg
# Writing to 20250623151113_4a032791c141c6f022bdc38c218efdf2_IMAG01_3.jpg(143,514bytes)

# %% [markdown]
# * 현재 요청된 페이지의 image 모두 다운로드 해보기

# %%
import requests
from bs4 import BeautifulSoup
import os

webtoon_url = 'https://comic.naver.com/webtoon/detail?titleId=654138&no=469&week=tue'

req_header = {
    'referer': webtoon_url,
    "user-agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/104.0.0.0 Safari/537.36"""
}

res = requests.get(webtoon_url)
print(res.status_code)

if res.ok:
    soup = BeautifulSoup(res.text, 'html.parser')
    print(len(soup.select("img[src$='.jpg']")))
    # print(len(soup.select("img[src^='https://image-comic.pstatic.net/webtoon/654138/469/20250602171933']")))
    print(len(soup.select("img[src*='IMAG01']"))) #일치함

# img src file명을 저장할 list 선언
img_url_list = list() # ['http://xxx/aa.jpg']
img_tags = soup.select("img[src*='IMAG01']") #img_tags의 타입은 Resultset [Tag, Tag]

for img_tag in img_tags: #img_tag 의 타입은 Tag <img>
    img_url = img_tag['src']
    img_url_list.append(img_url)
    #print(len(img_url_list), img_url_list[0:2])

#img 디렉토리가 없으면 생성하기
imgdir_name = 'img'
if not os.path.isdir(imgdir_name):
    os.mkdir(imgdir_name)

for jpg_url in img_url_list[:3]:
    res = requests.get(jpg_url, headers=req_header)
    if res.ok:
        img_data = res.content
        dir_name = os.path.join(imgdir_name, os.path.basename(jpg_url))
        with open(dir_name, 'wb') as file:
            print(f'Writing to {dir_name}({len(img_data):,} bytes)')
            file.write(img_data)
    else:
        print(f'Error Code = {res.status_code}')
# Out:
# 200
# 530
# 58
# Writing to img\20250602171933_dba536f73bd3aa91744af61932c22dff_IMAG01_1.jpg(146,639 bytes)
# Writing to img\20250602171933_dba536f73bd3aa91744af61932c22dff_IMAG01_2.jpg(141,814 bytes)
# Writing to img\20250602171933_dba536f73bd3aa91744af61932c22dff_IMAG01_3.jpg(121,197 bytes)

# %% [markdown]
# 리팩토링 코드

# %%
import requests
from bs4 import BeautifulSoup
import os

# 기본 설정
url = 'https://comic.naver.com/webtoon/detail?titleId=833255&no=3&week=tue'
req_header = {'referer': url}
imgdir_name = 'img'

# 이미지 저장 폴더가 없으면 생성
os.makedirs(imgdir_name, exist_ok=True)

# 웹 페이지 요청 및 확인
res = requests.get(url)
if not res.ok:
    print(f'Error Code = {res.status_code}')
    exit()

# 이미지 URL 추출
soup = BeautifulSoup(res.text, 'html.parser')
img_url_list = [img_tag['src'] for img_tag in soup.select("img[src*='IMAG01']")]

# 이미지 다운로드
for img_url in img_url_list:
    res = requests.get(img_url, headers=req_header)
    if res.ok:
        img_data = res.content
        file_path = os.path.join(imgdir_name, os.path.basename(img_url))
        with open(file_path, 'wb') as file:
            print(f'Writing to {file_path} ({len(img_data):,} bytes)')
            file.write(img_data)
    else:
        print(f'Error Code = {res.status_code} for {img_url}')
# Out:
# Writing to img\20241019203626_ee2218f8c6131e687ade8a9df8c9d052_IMAG01_1.jpg (164,266 bytes)
# Writing to img\20241019203626_ee2218f8c6131e687ade8a9df8c9d052_IMAG01_2.jpg (119,906 bytes)
# Writing to img\20241019203626_ee2218f8c6131e687ade8a9df8c9d052_IMAG01_3.jpg (130,933 bytes)
# Writing to img\20241019203626_ee2218f8c6131e687ade8a9df8c9d052_IMAG01_4.jpg (130,725 bytes)
# Writing to img\20241019203626_ee2218f8c6131e687ade8a9df8c9d052_IMAG01_5.jpg (134,506 bytes)
# Writing to img\20241019203626_ee2218f8c6131e687ade8a9df8c9d052_IMAG01_6.jpg (166,312 bytes)
# Writing to img\20241019203626_ee2218f8c6131e687ade8a9df8c9d052_IMAG01_7.jpg (135,069 bytes)
# Writing to img\20241019203626_ee2218f8c6131e687ade8a9df8c9d052_IMAG01_8.jpg (95,346 bytes)
# Writing to img\20241019203626_ee2218f8c6131e687ade8a9df8c9d052_IMAG01_9.jpg (160,655 bytes)
# Writing to img\20241019203626_ee2218f8c6131e687ade8a9df8c9d052_IMAG01_10.jpg (157,106 bytes)
# Writing to img\20241019203626_ee2218f8c6131e687ade8a9df8c9d052_IMAG01_11.jpg (159,141 bytes)
# Writing to img\20241019203626_ee2218f8c6131e687ade8a9df8c9d052_IMAG01_12.jpg (94,296 bytes)
# Writing to img\20241019203626_ee2218f8c6131e687ade8a9df8c9d052_IMAG01_13.jpg (91,062 bytes)
# Writing to img\20241019203626_ee2218f8c6131e687ade8a9df8c9d052_IMAG01_14.jpg (2,915 bytes)

# %% [markdown]
# ### 3. 파일 업로드 하기
# * http://httpbin.org/post 업로드 요청을 할 수 있는 url

# %%
import requests

upload_files = {
    'img1': open('f1.jpg','rb'),
    'img2': open('f2.jpg','rb')
}
print(upload_files)

url = 'http://httpbin.org/post'
# file 업로드 하려면 requests의 post 함수에 files 속성을 사용합니다.
res = requests.post(url,files=upload_files)
print(res.status_code)
print(type(res.json()))
#print(res.json())
print(res.json()['files']['img1'])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[20], line 4
#       1 import requests
#       3 upload_files = {
# ----> 4     'img1': open('f1.jpg','rb'),
#       5     'img2': open('f2.jpg','rb')
#       6 }
#       7 print(upload_files)
#       9 url = 'http://httpbin.org/post'
#
# File c:\Users\USER\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'f1.jpg'

# %% [markdown]
# ### 4. 캡챠(이미지) API 호출하기
# * urllib 사용
# * 1. 캡차 키 발급 요청
#   2. 캡차 이미지 요청
#   3. 사용자 입력값 검증 요청

# %%
# 캡차 키 발급 요청
import os
import sys
import urllib.request

client_id = "Hc0HDOhWhANwx7lHzoiu" # 개발자센터에서 발급받은 Client ID 값
client_secret = "geEoW5GhpW" # 개발자센터에서 발급받은 Client Secret 값

code = "0"
url = "https://openapi.naver.com/v1/captcha/nkey?code=" + code

#Request 객체 설정
request = urllib.request.Request(url)

#요청헤더 설정
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)

#서버에 request 전달
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {"key":"Iq7FHIk1w9O7xNNA"}

# %%
# 캡차 이미지 요청
import urllib.request

client_id = "Hc0HDOhWhANwx7lHzoiu" # 개발자센터에서 발급받은 Client ID 값
client_secret = "geEoW5GhpW" # 개발자센터에서 발급받은 Client Secret 값
key = "AdJVHH2DuUoLsr0l" # 캡차 Key 값
url = "https://openapi.naver.com/v1/captcha/ncaptcha.bin?key=" + key

request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    print("캡차 이미지 저장")
    response_body = response.read()
    with open('captcha.jpg', 'wb') as f:
        f.write(response_body)
else:
    print("Error Code:" + rescode)
# Out:
# 캡차 이미지 저장

# %%
#  사용자 입력값 검증 요청
import urllib.request

client_id = "Hc0HDOhWhANwx7lHzoiu" # 개발자센터에서 발급받은 Client ID 값
client_secret = "geEoW5GhpW" # 개발자센터에서 발급받은 Client Secret 값
code = "1"
key = "AdJVHH2DuUoLsr0l"
value = "HEN3YC"
url = "https://openapi.naver.com/v1/captcha/nkey?code=" + code + "&key=" + key + "&value=" + value

request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {"result":true,"responseTime":37.83}

# %% [markdown]
# * requests를 사용하는 코드로 변경하기
# * [requests docs](https://requests.readthedocs.io/en/latest/user/quickstart/)

# %%
# 사용자 입력값 검증 요청

import os
from dotenv import load_dotenv
import requests

# .env 파일에서 환경 변수 로드
load_dotenv()

# 환경 변수에서 값 읽기
client_id = os.getenv("NAVER_CLIENT_ID")  # .env 파일의 NAVER_CLIENT_ID
client_secret = os.getenv("NAVER_CLIENT_SECRET")  # .env 파일의 NAVER_CLIENT_SECRET
key = "Iq7FHIk1w9O7xNNA"  # .env 파일의 NAVER_CAPTCHA_KEY

# 사용자 입력값
code = "1"
value = "93S5VBK"  # 실제 사용시 사용자 입력값으로 대체 필요

# URL 구성
# query string key1=value1&key2=value2
url = f"https://openapi.naver.com/v1/captcha/nkey?code={code}&key={key}&value={value}"

# 요청 헤더
headers = {
    "X-Naver-Client-Id": client_id,
    "X-Naver-Client-Secret": client_secret
}

# 요청 보내기
try:
    response = requests.get(url, headers=headers)
    response.raise_for_status()  # 4xx, 5xx 오류 발생시 예외 발생
    
    # 응답 처리
    print(response.text)
    
except requests.exceptions.RequestException as e:
    print(f"Error occurred: {e}")
    print(f"Status Code: {response.status_code if 'response' in locals() else 'N/A'}")
# Out:
# Error occurred: 400 Client Error: Bad Request for url: https://openapi.naver.com/v1/captcha/nkey?code=1&key=Iq7FHIk1w9O7xNNA&value=93S5VBK
# Status Code: 400

# %% [markdown]
# ### 5. 블로그 검색하기

# %%
import requests
from pprint import pprint
import os
from dotenv import load_dotenv

# .env 파일에서 환경 변수 로드
load_dotenv()

# 환경 변수에서 값 읽기
client_id = os.getenv("NAVER_CLIENT_ID")  # .env 파일의 NAVER_CLIENT_ID
client_secret = os.getenv("NAVER_CLIENT_SECRET")  # .env 파일의 NAVER_CLIENT_SECRET

headers = {
    'X-Naver-Client-Id': client_id,
    'X-Naver-Client-Secret': client_secret,
}

# query string 문자열을 dict 선언
payload = {
    'query': '파이썬',
    'display': 100,
    'sort': 'date'
}

url = 'https://openapi.naver.com/v1/search/blog.json' #?query=파이썬&display=100&sort=sim

# requests get(url, params, headers) 요청 
res = requests.get(url, params=payload, headers=headers)
# json() 함수로 응답 결과 가져오기
items_data = res.json()['items']
print(type(res.json()))
#pprint(res.json())
print(len(items_data), type(items_data), type(items_data[0]))
pprint(items_data[0])

#[{},{},{}] 
# [] - 100 개의 데이터, {title:'',link:''} - 1개의 블로그 글 데이터
# Out:
# <class 'dict'>
# 100 <class 'list'> <class 'dict'>
# {'bloggerlink': 'blog.naver.com/onuri2005',
#  'bloggername': '오렌지사과의 사진첩',
#  'description': '지난 글: [<b>파이썬</b> 부록 K4] 기초자산의 분산 투자 효과를 살펴보자 (+퀀트킹을 이용한 퀀트 '
#                 '투자) 참고: 이 연재는 <b>파이썬</b>을 사용하는 기초적인 방법을 설명하지 않습니다. '
#                 '<b>파이썬</b>에 대한 간단한 소개와... ',
#  'link': 'https://blog.naver.com/onuri2005/223944138878',
#  'postdate': '20250723',
#  'title': '[<b>파이썬</b> 부록 K5] 기초 자산과 퀀트 전략에 분산 투자해 보자... '}

# %%
# 'title' , 'bloggername' , 'description' , 'bloggerlink' , 'link'
items_list = list()
item_list = []
for item in items_data:
#     print(item)
    item_list.append(item['title'])
    item_list.append(item['bloggername'])
    item_list.append(item['description'])
    item_list.append(item['bloggerlink'])
    item_list.append(item['link'])
    item_list.append(item['postdate'])

    items_list.append(item_list)
    item_list = []

print(items_list) #[[],[],[]]

# 'data/nhnblog.txt' 파일 생성하기
with open('data/nhnblog.txt','w',encoding="utf-8")as file:
    for items in items_list:
        for item in items:
            item = item + '\n'
            file.write(item)
        file.write('-'*150+'\n')
# Out:
# [['[<b>파이썬</b> 부록 K5] 기초 자산과 퀀트 전략에 분산 투자해 보자... ', '오렌지사과의 사진첩', '지난 글: [<b>파이썬</b> 부록 K4] 기초자산의 분산 투자 효과를 살펴보자 (+퀀트킹을 이용한 퀀트 투자) 참고: 이 연재는 <b>파이썬</b>을 사용하는 기초적인 방법을 설명하지 않습니다. <b>파이썬</b>에 대한 간단한 소개와... ', 'blog.naver.com/onuri2005', 'https://blog.naver.com/onuri2005/223944138878', '20250723'], ['공학 교구활용 안내', '미리캠퍼스', '9 <b>파이썬</b>을 이용한 그림/영상 그리기와 편집 (6시간) 간단한 프로그래밍을 통해 그림이나 영상을 생성하고 편집 가능한 기능 실습 10 ChatGPT 활용 틀과 이를 활용한 게임 개발 실습 생성형 AI의 발전과 적용... ', 'blog.naver.com/miri-campus', 'https://blog.naver.com/miri-campus/223944128778', '20250723'], ['2025.7.16 <b>파이썬</b>', 'kevinpanda0801님의 블로그', '', 'blog.naver.com/kevinpanda0801', 'https://blog.naver.com/kevinpanda0801/223944120302', '20250723'], ['하루 목표 달성률 높이는 체크리스트 작성법', '도형레코드 DH record', "대신 '일주일 안에 <b>파이썬</b> 기본 문법 강의 3개 수강하고 예제 코드 따라 하기'와 같이 현실적인 목표를 설정하는 것이 바람직합니다. 목표 설정 시 현재 자신의 역량 수준을 객관적으로 평가하는 과정이... ", 'blog.naver.com/jigengs', 'https://blog.naver.com/jigengs/223911881591', '20250723'], ['spyder IDE로 python 사용하기', '세상을 가치있게', 'Spyder의 사용은 anacoda 를 설치하여 사용하는 것을 권장: Anaconda 프로그램을 설치하면, Python과 함께 Jupyter Notebook, NumPy, pandas, matplotlib 등 <b>파이썬</b>으로 데이터 사이언스를... ', 'blog.naver.com/gwihyeonseo', 'https://blog.naver.com/gwihyeonseo/223944119740', '20250723'], ['[python] pickle, copy, mask', '세상을 가치있게', 'pickle 모듈은 <b>파이썬</b> 객체를 파일에 저장하거나 네트워크를 통해 전송할 수도 있다. pickle.dump(): <b>파이썬</b> 객체를 파일에 저장하는 데 사용되며, 첫 번째 인자는 저장할 객체, 두 번째 인자는 파일... ', 'blog.naver.com/gwihyeonseo', 'https://blog.naver.com/gwihyeonseo/223944116543', '20250723'], ['<b>파이썬</b> Python 기본 개념 정리표', '시고르강쥐의 컨텐츠&마케팅', '<b>파이썬</b>, 왜 배워야 할까요? <b>파이썬</b>은 자연어와 유사한 간결한 문법을 가지고 있어 배우기 쉽습니다. 또한, AI, 머신러닝, 데이터 분석, 웹 개발 등 다양한 분야에서 활용되며 풍부한... ', 'blog.naver.com/bizdigitalmarketing', 'https://blog.naver.com/bizdigitalmarketing/223944114721', '20250723'], ['수원 코딩과외 초등 중등 <b>파이썬</b> 자바스크립트', '합격매뉴얼ZIP', '수원 코딩과외 초등 중등 <b>파이썬</b> 자바스크립트 요즘 들어 ‘코딩 교육’이라는 말, 여기저기서 자주... 특히 수원 코딩과외 초등 중등 <b>파이썬</b> 자바스크립트처럼 맞춤형 일대일 수업을 진행하면, 각 아이의 성향과... ', 'blog.naver.com/rrers6025', 'https://blog.naver.com/rrers6025/223944111393', '20250723'], ['고령자 돌봄 로봇 운영 관리자로서의 기술 기반 직업', 'bokkli86님의 블로그', '기초 프로그래밍 능력 (<b>파이썬</b>, C++ 등) 하드웨어 기본 지식 데이터 분석 및 해석 기술 노년층 심리 이해... 기초 코딩 배우기 - <b>파이썬</b> 같은 언어부터 시작해보는 건 어떨까요? 코딩은 요즘 정말 중요해졌어요!... ', 'blog.naver.com/bokkli86', 'https://blog.naver.com/bokkli86/223944107133', '20250723'], ['눈시림 없는 온가족 선크림 블록 베몽테스 <b>파이썬</b> 가드', '더 뷰티 파마씨', '바른듯,안 바른 듯 <b>파이썬</b>카드 선크림 자외선차단,주름개선 미백 3중 기능성 SPF50+ / PA++++ 백탁없이... 이런 고객님들을 위한 <b>파이썬</b> 카드 ✅미백,주름 개선이 포함된 기능성 선크림을 찾으시는 분 ✅예민해진... ', 'blog.naver.com/mellechoi', 'https://blog.naver.com/mellechoi/223944104236', '20250723'], ['<b>파이썬</b>: 프로그래밍 언어의 왕좌를 지키는 이유는?', '별의속삭임', '<b>파이썬</b>의 유래와 발전 <b>파이썬</b>은 1991년귀도 반 로섬이 개발한 프로그래밍 언어입니다. 그 이름은 그가 좋아하던 영국의 코미디 그룹, 몬티 <b>파이썬</b>에서 따온 것입니다. 이 언어는 직관적인 문법과 다양한... ', 'blog.naver.com/einnlsb739', 'https://blog.naver.com/einnlsb739/223944101264', '20250723'], ['구미교육지원청 2025년 구미지역 수학축제 열어!', '뉴스라이프', '이 외에도 중학생들을 대상으로 하는 큐브아트, <b>파이썬</b> 로봇코딩 등과 같은 수학주제탐구 프로그램을 통해 학생들이 수학에 더 관심을 갖을 수 있도록 준비했다. 이번 행사에 참여한 학부모는 &quot;매년 구미지역... ', 'blog.naver.com/newslife9366', 'https://blog.naver.com/newslife9366/223944096878', '20250723'], ['<b>파이썬</b> 람다 Lambda', 'Le mieux est l’ennemi du bien', 'Python의 람다 함수는 lambda 키워드를 사용하여 한 줄로 정의할 수 있는 익명 함수이다. 일반적인 함수와 달리 이름이 없고, 간단한 연산이나 변환 로직을 표현할 때 주로 사용하라. map(), filter(), sorted... ', 'blog.naver.com/csj4032', 'https://blog.naver.com/csj4032/223944096723', '20250723'], ['프로그래밍언어의 기초부터 배우고 싶다면?... ', '화린(花吝) : 꽃처럼 너를 아껴주는곳', "<b>파이썬</b>은 배우기 쉽고 간결한 문법 덕분에 코딩 입문자에게 최고의 언어로 손꼽혀요. 인공지능(AI), 데이터 분석, 웹 개발, 자동화 등 정말 다양한 분야에서 활용되는 '만능 언어'입니다. <b>파이썬</b> 하나만 잘... ", 'blog.naver.com/hwa__rin', 'https://blog.naver.com/hwa__rin/223944093841', '20250723'], ['빅데이터분석기사 자격증 취득 공부방법', 'IT살펴보기-테크로 통하다', '오늘도 즐거운 하루 보내세요 #빅데이터분석기사 #빅데이터분석기사자격증 #빅데이터분석기사학원 #빅데이터분석기사실기 #빅데이터분석기사필기 #<b>파이썬</b> #AI관련자격증', 'blog.naver.com/tu0922', 'https://blog.naver.com/tu0922/223944080994', '20250723'], ['☕ 자바(Java) 언어의 특징 총정리', ...
